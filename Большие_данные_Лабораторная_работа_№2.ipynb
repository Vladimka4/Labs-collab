# %% [markdown]
# # Лабораторная работа № 2

# %% [markdown]
# [Теория](https://colab.research.google.com/drive/1RznMeu1JghbgMkv35DJGbUIXiiUK6IeQ?usp=sharing)

# %% [markdown]
# Этапы выполнения:
#
# - **Шаг 1.** Импортировать библиотеки, загрузить содержимое файла, переименовать признаки:
# anketa_ist.csv
#
# - **Шаг 2.** Выполнить токенизацию (используйте признаки про фильмы, ожидание от обучения, виды спорта)
# - **Шаг 3.** Выполнить лемматизацию и удалить стоп-слова и знаки препинания (для признаков из шага 2)
# - **Шаг 4.** Выполнить подсчёт количества вхождений слов (для признаков из шага 2)
# - **Шаг 5.** Построить гистограмму по популярным видам спорта (20 видов), treepmap по фильмам (20 слов), облако слов из топ 50 слов по признаку ожидание от обучения.
#
# - ** Проанализировать признак Любимый предмет

# %%
import re
import string
import nltk # библиотека nltk
from nltk.tokenize import word_tokenize # готовые токенизаторы библиотеки nltk
from nltk.corpus import stopwords

import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(13, 10))

import pandas as pd
import numpy as np
from PIL import Image
import datetime as dt

import plotly.express as px
import plotly.graph_objects as go
from plotly import subplots

from pymorphy2 import MorphAnalyzer

from collections import Counter
from wordcloud import WordCloud

import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('https://github.com/OlesiaAngel/DataAnalitics/raw/main/%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D0%B5/examples/anketa_ist.csv',
                sep=';')
df
